# %%
import requests
import librosa
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os

# %% [markdown]
# GLOBALS

# %%
data_dir = 'data'

# %%
requests.get(f'https://xeno-canto.org/api/2/recordings?query=gen:Acrocephalus+cnt:russia').json()['recordings']
# Out:
# [{'id': '835032',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Tonya Avangardnaya, Kamyzyaksky District, Astrakhan Oblast',
#   'lat': '45.685',
#   'lng': '48.0622',
#   'alt': '-30',
#   'type': 'alarm call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/835032',
#   'file': 'https://xeno-canto.org/835032/download',
#   'file-name': 'XC835032-Acrocephalus-arundinaceus-0909_080143,р.-Кизань-разливы,A-alarm.wav',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC835032-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC835032-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC835032-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC835032-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC835032-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC835032-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC835032-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-nd/4.0/',
#   'q': 'A',
#   'length': '0:19',
#   'time': '08:00',
#   'date': '2023-09-09',
#   'uploaded': '2023-10-10',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '88200'},
#  {'id': '805109',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': 'arundinaceus',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Mikhail Nevsky',
#   'cnt': 'Russian Federation',
#   'loc': 'Teleshovo, Lotoshinsky District, Moscow Oblast',
#   'lat': '56.2221',
#   'lng': '35.9599',
#   'alt': '130',
#   'type': 'song',
#   'sex': 'male',
#   'stage': 'adult',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/805109',
#   'file': 'https://xeno-canto.org/805109/download',
#   'file-name': 'XC805109-Дроздовидка-(mp3cut.net).mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/VHGBYLBHIH/ffts/XC805109-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/VHGBYLBHIH/ffts/XC805109-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/VHGBYLBHIH/ffts/XC805109-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/VHGBYLBHIH/ffts/XC805109-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/VHGBYLBHIH/wave/XC805109-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/VHGBYLBHIH/wave/XC805109-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/VHGBYLBHIH/wave/XC805109-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '0:31',
#   'time': '16:20',
#   'date': '2023-05-27',
#   'uploaded': '2023-05-29',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': 'phone',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '488300',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Kozlovskiy Rayon, Chuvashia',
#   'lat': '55.9136',
#   'lng': '48.068',
#   'alt': '80',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/488300',
#   'file': 'https://xeno-canto.org/488300/download',
#   'file-name': 'XC488300-Acrocephalus arundinaceus 190607_034, AAB.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC488300-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC488300-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC488300-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC488300-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC488300-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC488300-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC488300-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '1:04',
#   'time': '08:00',
#   'date': '2018-06-07',
#   'uploaded': '2019-07-19',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '325359',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Dmitry Kulakov',
#   'cnt': 'Russian Federation',
#   'loc': "Nemanskiy rayon, Kaliningradskaya oblast'",
#   'lat': '55.0481',
#   'lng': '22.1758',
#   'alt': '10',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/325359',
#   'file': 'https://xeno-canto.org/325359/download',
#   'file-name': 'XC325359- камышовка (Acrocephalus arundinaceus) (27.06.16).mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/CNORMZSGIQ/ffts/XC325359-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/CNORMZSGIQ/ffts/XC325359-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/CNORMZSGIQ/ffts/XC325359-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/CNORMZSGIQ/ffts/XC325359-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/CNORMZSGIQ/wave/XC325359-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/CNORMZSGIQ/wave/XC325359-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/CNORMZSGIQ/wave/XC325359-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '0:48',
#   'time': '10:30',
#   'date': '2016-06-27',
#   'uploaded': '2016-07-03',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '270357',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Polyana, Yurinskiy rayon, Respublika Mariy El',
#   'lat': '56.2232',
#   'lng': '46.0557',
#   'alt': '60',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/270357',
#   'file': 'https://xeno-canto.org/270357/download',
#   'file-name': 'XC270357-Acrocephalus arundinaceus 150624_021,AAAA1.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270357-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270357-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270357-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270357-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270357-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270357-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270357-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '4:48',
#   'time': '15:30',
#   'date': '2015-06-24',
#   'uploaded': '2015-08-25',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '270355',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Polyana, Yurinskiy rayon, Respublika Mariy El',
#   'lat': '56.2232',
#   'lng': '46.0557',
#   'alt': '60',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/270355',
#   'file': 'https://xeno-canto.org/270355/download',
#   'file-name': 'XC270355-Acrocephalus arundinaceus 150624_021,AAAA3.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270355-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270355-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270355-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270355-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270355-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270355-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270355-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '5:50',
#   'time': '15:30',
#   'date': '2015-06-24',
#   'uploaded': '2015-08-25',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '270354',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Polyana, Yurinskiy rayon, Respublika Mariy El',
#   'lat': '56.2232',
#   'lng': '46.0557',
#   'alt': '60',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/270354',
#   'file': 'https://xeno-canto.org/270354/download',
#   'file-name': 'XC270354-Acrocephalus arundinaceus 150624_021,AAAA2.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270354-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270354-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270354-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270354-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270354-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270354-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270354-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '5:41',
#   'time': '15:30',
#   'date': '2015-06-24',
#   'uploaded': '2015-08-25',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '270351',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Polyana, Yurinskiy rayon, Respublika Mariy El',
#   'lat': '56.2232',
#   'lng': '46.0557',
#   'alt': '60',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/270351',
#   'file': 'https://xeno-canto.org/270351/download',
#   'file-name': 'XC270351-Acrocephalus arundinaceus 150624_021,AAAA3+.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270351-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270351-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270351-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270351-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270351-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270351-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270351-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '1:32',
#   'time': '15:30',
#   'date': '2015-06-24',
#   'uploaded': '2015-08-25',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '270350',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Polyana, Yurinskiy rayon, Respublika Mariy El',
#   'lat': '56.2232',
#   'lng': '46.0557',
#   'alt': '60',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/270350',
#   'file': 'https://xeno-canto.org/270350/download',
#   'file-name': 'XC270350-Acrocephalus arundinaceus 150624_021,AAAA2+.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270350-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270350-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270350-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270350-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270350-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270350-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270350-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '5:58',
#   'time': '15:30',
#   'date': '2015-06-24',
#   'uploaded': '2015-08-25',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '270348',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Polyana, Yurinskiy rayon, Respublika Mariy El',
#   'lat': '56.2232',
#   'lng': '46.0557',
#   'alt': '60',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/270348',
#   'file': 'https://xeno-canto.org/270348/download',
#   'file-name': 'XC270348-Acrocephalus arundinaceus 150624_021,AAAA1+.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270348-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270348-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270348-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270348-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270348-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270348-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270348-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '5:59',
#   'time': '15:30',
#   'date': '2015-06-24',
#   'uploaded': '2015-08-25',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '270346',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Polyana, Yurinskiy rayon, Respublika Mariy El',
#   'lat': '56.2232',
#   'lng': '46.0557',
#   'alt': '60',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/270346',
#   'file': 'https://xeno-canto.org/270346/download',
#   'file-name': 'XC270346-Acrocephalus arundinaceus 150624_021,AAAA+.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270346-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270346-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270346-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC270346-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270346-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270346-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC270346-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '5:55',
#   'time': '15:30',
#   'date': '2015-06-24',
#   'uploaded': '2015-08-25',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '147908',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Poretskiy rayon, Chuvashia',
#   'lat': '55.2724',
#   'lng': '46.3995',
#   'alt': '90',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/147908',
#   'file': 'https://xeno-canto.org/147908/download',
#   'file-name': 'XC147908- Кирский 17.6.2007-дроздовидная кам-ка-3.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC147908-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC147908-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC147908-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC147908-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC147908-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC147908-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC147908-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'A',
#   'length': '0:50',
#   'time': '08:00',
#   'date': '2007-06-17',
#   'uploaded': '2013-09-20',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '147906',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Poretskiy rayon, Chuvashia',
#   'lat': '55.2726',
#   'lng': '46.3978',
#   'alt': '90',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/147906',
#   'file': 'https://xeno-canto.org/147906/download',
#   'file-name': 'XC147906- Кирский 17.6.2007- дроздовидная камышевка-1.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC147906-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC147906-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC147906-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC147906-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC147906-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC147906-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC147906-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'A',
#   'length': '0:30',
#   'time': '08:00',
#   'date': '2007-06-17',
#   'uploaded': '2013-09-20',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '106932',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin   ',
#   'cnt': 'Russian Federation',
#   'loc': 'Alatyr',
#   'lat': '54.8609',
#   'lng': '46.5739',
#   'alt': '130',
#   'type': 'alarm call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/106932',
#   'file': 'https://xeno-canto.org/106932/download',
#   'file-name': '1352.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC106932-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC106932-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC106932-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC106932-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC106932-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC106932-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC106932-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-nd/2.5/',
#   'q': 'A',
#   'length': '0:24',
#   'time': '8-20',
#   'date': '2012-08-05',
#   'uploaded': '2012-08-06',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '488301',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Kozlovskiy Rayon, Chuvashia',
#   'lat': '55.9136',
#   'lng': '48.068',
#   'alt': '80',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/488301',
#   'file': 'https://xeno-canto.org/488301/download',
#   'file-name': 'XC488301-Acrocephalus arundinaceus 190607_045, AABB.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC488301-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC488301-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC488301-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC488301-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC488301-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC488301-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC488301-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '6:16',
#   'time': '08:00',
#   'date': '2018-06-07',
#   'uploaded': '2019-07-19',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '448264',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Vadim Ivushkin ',
#   'cnt': 'Russian Federation',
#   'loc': 'Cherkasskiy, Kanevskoy District, Krasnodarskiy kray',
#   'lat': '46.1403',
#   'lng': '38.9163',
#   'alt': '0',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/448264',
#   'file': 'https://xeno-canto.org/448264/download',
#   'file-name': 'XC448264-WS330228.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/ffts/XC448264-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/ffts/XC448264-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/ffts/XC448264-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/ffts/XC448264-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/wave/XC448264-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/wave/XC448264-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/wave/XC448264-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '0:45',
#   'time': '16:30',
#   'date': '2009-06-11',
#   'uploaded': '2019-01-01',
#   'also': [],
#   'rmk': 'Combined three files.',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '366044',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Priyutnenskiy rayon, Respublika Kalmykiya',
#   'lat': '45.9968',
#   'lng': '43.5646',
#   'alt': '10',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/366044',
#   'file': 'https://xeno-canto.org/366044/download',
#   'file-name': 'XC366044-Acrocephalus arundinaceus, L-170413_004,Маныч,залив,утр,A.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC366044-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC366044-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC366044-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC366044-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC366044-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC366044-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC366044-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '0:10',
#   'time': '09:00',
#   'date': '2017-04-13',
#   'uploaded': '2017-04-24',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '182276',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Dombarovsky District, Orenburgskaya oblast',
#   'lat': '50.732',
#   'lng': '59.6352',
#   'alt': '280',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/182276',
#   'file': 'https://xeno-canto.org/182276/download',
#   'file-name': 'XC182276-Acrocephalus arundinaceus zarudnyi 140518_022,B.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC182276-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC182276-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC182276-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC182276-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC182276-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC182276-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC182276-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '2:03',
#   'time': '05:00',
#   'date': '2014-05-18',
#   'uploaded': '2014-06-17',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '182275',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': 'zarudnyi',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Dombarovsky District, Orenburgskaya oblast',
#   'lat': '50.732',
#   'lng': '59.6352',
#   'alt': '280',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/182275',
#   'file': 'https://xeno-canto.org/182275/download',
#   'file-name': 'XC182275-Acrocephalus arundinaceus zarudnyi 140518_022,BB.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC182275-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC182275-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC182275-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC182275-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC182275-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC182275-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC182275-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '1:13',
#   'time': '05:00',
#   'date': '2014-05-18',
#   'uploaded': '2014-06-17',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '147907',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Poretskiy rayon, Chuvashia',
#   'lat': '55.2715',
#   'lng': '46.398',
#   'alt': '80',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/147907',
#   'file': 'https://xeno-canto.org/147907/download',
#   'file-name': 'XC147907- Кирский 17.6.2007-дроздовидная кам-ка-2 и самка чирка свистунка.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC147907-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC147907-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC147907-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC147907-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC147907-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC147907-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC147907-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'B',
#   'length': '1:16',
#   'time': '08:00',
#   'date': '2007-06-17',
#   'uploaded': '2013-09-20',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '106398',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Alatyr',
#   'lat': '54.8609',
#   'lng': '46.5739',
#   'alt': '120',
#   'type': 'call, calls young',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/106398',
#   'file': 'https://xeno-canto.org/106398/download',
#   'file-name': '1244.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC106398-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC106398-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC106398-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC106398-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC106398-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC106398-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC106398-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-nd/2.5/',
#   'q': 'B',
#   'length': '2:15',
#   'time': '7-30',
#   'date': '2012-07-24',
#   'uploaded': '2012-07-29',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '187084',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': 'arundinaceus',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Novocheboksarsk, gorod Novocheboksarsk, Chuvash Republic',
#   'lat': '56.1056',
#   'lng': '47.5392',
#   'alt': '60',
#   'type': 'call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/187084',
#   'file': 'https://xeno-canto.org/187084/download',
#   'file-name': 'XC187084-Acrocephalus arundinaceus 140713_007,C.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC187084-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC187084-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC187084-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC187084-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC187084-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC187084-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC187084-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:14',
#   'time': '08:30',
#   'date': '2014-07-13',
#   'uploaded': '2014-07-14',
#   'also': ['Tringa glareola'],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '182277',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': 'zarudnyi',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Dombarovsky District, Orenburgskaya oblast',
#   'lat': '50.732',
#   'lng': '59.6352',
#   'alt': '280',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/182277',
#   'file': 'https://xeno-canto.org/182277/download',
#   'file-name': 'XC182277-Acrocephalus arundinaceus zarudnyi 140518_020,CB.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC182277-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC182277-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC182277-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC182277-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC182277-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC182277-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC182277-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '2:59',
#   'time': '05:00',
#   'date': '2014-05-18',
#   'uploaded': '2014-06-17',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '133461',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Novocheboksarsk, gorod Novocheboksarsk, Chuvashia',
#   'lat': '56.1087',
#   'lng': '47.5543',
#   'alt': '60',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/133461',
#   'file': 'https://xeno-canto.org/133461/download',
#   'file-name': 'XC133461-8022_2013-05-12 новочебоксарск, отчистные, 4-30, Acrocephalus arundinaceus, Д, .MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC133461-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC133461-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC133461-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC133461-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC133461-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC133461-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC133461-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'C',
#   'length': '0:02',
#   'time': '04:30',
#   'date': '2013-05-12',
#   'uploaded': '2013-05-12',
#   'also': ['Chroicocephalus ridibundus'],
#   'rmk': 'a loud shout, the voice of cattail marshes were overgrown',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '187083',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': 'arundinaceus',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Novocheboksarsk, gorod Novocheboksarsk, Chuvash Republic',
#   'lat': '56.1056',
#   'lng': '47.5392',
#   'alt': '60',
#   'type': 'call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/187083',
#   'file': 'https://xeno-canto.org/187083/download',
#   'file-name': 'XC187083-Acrocephalus arundinaceus 140713_006,C.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC187083-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC187083-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC187083-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC187083-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC187083-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC187083-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC187083-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'D',
#   'length': '0:15',
#   'time': '08:30',
#   'date': '2014-07-13',
#   'uploaded': '2014-07-14',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '138832',
#   'gen': 'Acrocephalus',
#   'sp': 'arundinaceus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Great Reed Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Alatyr',
#   'lat': '54.8609',
#   'lng': '46.5739',
#   'alt': '80',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/138832',
#   'file': 'https://xeno-canto.org/138832/download',
#   'file-name': 'XC138832-8044_8.06.2013, Алатырь, отчистные, 8-00, дроздовидка, Д .MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC138832-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC138832-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC138832-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC138832-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC138832-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC138832-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC138832-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'D',
#   'length': '3:16',
#   'time': '08:00',
#   'date': '2013-06-08',
#   'uploaded': '2013-06-18',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '805634',
#   'gen': 'Acrocephalus',
#   'sp': 'orientalis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Oriental Reed Warbler',
#   'rec': 'Vadim Ivushkin ',
#   'cnt': 'Russian Federation',
#   'loc': 'Komsomolsky District, Khabarovsk Krai',
#   'lat': '50.8245',
#   'lng': '137.4735',
#   'alt': '20',
#   'type': 'song',
#   'sex': 'male',
#   'stage': 'adult',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/805634',
#   'file': 'https://xeno-canto.org/805634/download',
#   'file-name': 'XC805634-25_05_94дроздtolstokluvaya-16_XII.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/ffts/XC805634-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/ffts/XC805634-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/ffts/XC805634-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/ffts/XC805634-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/wave/XC805634-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/wave/XC805634-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/wave/XC805634-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '0:24',
#   'time': '11:30',
#   'date': '1994-05-25',
#   'uploaded': '2023-05-31',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '25_05_94дроздtolstokluvaya 16_XII',
#   'auto': 'yes',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '805633',
#   'gen': 'Acrocephalus',
#   'sp': 'orientalis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Oriental Reed Warbler',
#   'rec': 'Vadim Ivushkin ',
#   'cnt': 'Russian Federation',
#   'loc': 'Komsomolsky District, Khabarovsk Krai',
#   'lat': '50.8245',
#   'lng': '137.4735',
#   'alt': '20',
#   'type': 'song',
#   'sex': 'male',
#   'stage': 'adult',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/805633',
#   'file': 'https://xeno-canto.org/805633/download',
#   'file-name': 'XC805633-25_05_94дроздtolstokluvaya-17_XII.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/ffts/XC805633-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/ffts/XC805633-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/ffts/XC805633-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/ffts/XC805633-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/wave/XC805633-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/wave/XC805633-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/ROPPXDGZJF/wave/XC805633-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '0:52',
#   'time': '11:30',
#   'date': '1994-05-25',
#   'uploaded': '2023-05-31',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '27_05_94_shirkuku 7',
#   'auto': 'yes',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '485458',
#   'gen': 'Acrocephalus',
#   'sp': 'orientalis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Oriental Reed Warbler',
#   'rec': 'Stanislas Wroza',
#   'cnt': 'Russian Federation',
#   'loc': 'Torma Lake, Buryatia',
#   'lat': '51.5641',
#   'lng': '107.0133',
#   'alt': '550',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/485458',
#   'file': 'https://xeno-canto.org/485458/download',
#   'file-name': 'XC485458-2019-06-24 Ulan Ude Orongoi lake et lacs sales de Gusionizerk Rousserolle d Orient chant +.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/ffts/XC485458-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/ffts/XC485458-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/ffts/XC485458-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/ffts/XC485458-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/wave/XC485458-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/wave/XC485458-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/wave/XC485458-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '2:36',
#   'time': '10:30',
#   'date': '2019-06-24',
#   'uploaded': '2019-07-08',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '48000'},
#  {'id': '485457',
#   'gen': 'Acrocephalus',
#   'sp': 'orientalis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Oriental Reed Warbler',
#   'rec': 'Stanislas Wroza',
#   'cnt': 'Russian Federation',
#   'loc': 'Torma Lake, Buryatia',
#   'lat': '51.5641',
#   'lng': '107.0133',
#   'alt': '550',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/485457',
#   'file': 'https://xeno-canto.org/485457/download',
#   'file-name': 'XC485457-2019-06-24 Ulan Ude Orongoi lake et lacs sales de Gusionizerk Rousserolle d Orient chant + 2.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/ffts/XC485457-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/ffts/XC485457-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/ffts/XC485457-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/ffts/XC485457-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/wave/XC485457-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/wave/XC485457-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/SDPCHKOHRH/wave/XC485457-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '0:57',
#   'time': '10:30',
#   'date': '2019-06-24',
#   'uploaded': '2019-07-08',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '48000'},
#  {'id': '389049',
#   'gen': 'Acrocephalus',
#   'sp': 'orientalis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Oriental Reed Warbler',
#   'rec': 'Alex Thomas',
#   'cnt': 'Russian Federation',
#   'loc': 'Muraviovka Park',
#   'lat': '49.8699',
#   'lng': '127.6447',
#   'alt': '120',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/389049',
#   'file': 'https://xeno-canto.org/389049/download',
#   'file-name': 'XC389049-170613_04_China-RS_G.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/JUKYCLSXAP/ffts/XC389049-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/JUKYCLSXAP/ffts/XC389049-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/JUKYCLSXAP/ffts/XC389049-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/JUKYCLSXAP/ffts/XC389049-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/JUKYCLSXAP/wave/XC389049-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/JUKYCLSXAP/wave/XC389049-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/JUKYCLSXAP/wave/XC389049-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '5:25',
#   'time': '01:00',
#   'date': '2017-06-13',
#   'uploaded': '2017-10-09',
#   'also': ['Rallus indicus',
#    'Asio otus',
#    'Zapornia paykullii',
#    'Acrocephalus bistrigiceps',
#    'Helopsaltes certhiola'],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '340040',
#   'gen': 'Acrocephalus',
#   'sp': 'orientalis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Oriental Reed Warbler',
#   'rec': 'Tom Wulf',
#   'cnt': 'Russian Federation',
#   'loc': 'Muraviovka Park',
#   'lat': '49.8699',
#   'lng': '127.6447',
#   'alt': '120',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/340040',
#   'file': 'https://xeno-canto.org/340040/download',
#   'file-name': 'XC340040-Oriental Reed Warbler song 20160531 1655 RUS OA Muraviovka Park TW LS_5.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/XVXHTBZRRW/ffts/XC340040-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/XVXHTBZRRW/ffts/XC340040-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/XVXHTBZRRW/ffts/XC340040-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/XVXHTBZRRW/ffts/XC340040-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/XVXHTBZRRW/wave/XC340040-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/XVXHTBZRRW/wave/XC340040-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/XVXHTBZRRW/wave/XC340040-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '2:40',
#   'time': '16:55',
#   'date': '2016-05-31',
#   'uploaded': '2016-10-25',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '340037',
#   'gen': 'Acrocephalus',
#   'sp': 'orientalis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Oriental Reed Warbler',
#   'rec': 'Tom Wulf',
#   'cnt': 'Russian Federation',
#   'loc': 'Muraviovka Park',
#   'lat': '49.8699',
#   'lng': '127.6447',
#   'alt': '120',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/340037',
# ...
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Batyrevskiy rayon, Chuvash Republic',
#   'lat': '55.0409',
#   'lng': '47.7274',
#   'alt': '150',
#   'type': 'alarm call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/189752',
#   'file': 'https://xeno-canto.org/189752/download',
#   'file-name': 'XC189752-Acrocephalus palustris 0722_082547,В1.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC189752-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC189752-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC189752-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC189752-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC189752-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC189752-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC189752-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:30',
#   'time': '07:00',
#   'date': '2014-07-22',
#   'uploaded': '2014-08-04',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '189751',
#   'gen': 'Acrocephalus',
#   'sp': 'palustris',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Marsh Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Batyrevskiy rayon, Chuvash Republic',
#   'lat': '55.0409',
#   'lng': '47.7274',
#   'alt': '150',
#   'type': 'call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/189751',
#   'file': 'https://xeno-canto.org/189751/download',
#   'file-name': 'XC189751-Acrocephalus palustris 0722_082547,В.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC189751-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC189751-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC189751-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC189751-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC189751-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC189751-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC189751-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:46',
#   'time': '07:00',
#   'date': '2014-07-22',
#   'uploaded': '2014-08-04',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '149261',
#   'gen': 'Acrocephalus',
#   'sp': 'palustris',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Marsh Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Zvenigovsky District, Mari El Republic',
#   'lat': '56.155',
#   'lng': '47.6568',
#   'alt': '60',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/149261',
#   'file': 'https://xeno-canto.org/149261/download',
#   'file-name': 'XC149261-001_21.05.2008, Сидельниково, бол кам, ВВ.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC149261-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC149261-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC149261-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC149261-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC149261-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC149261-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC149261-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'C',
#   'length': '1:47',
#   'time': '18:00',
#   'date': '2008-05-21',
#   'uploaded': '2013-09-30',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '139010',
#   'gen': 'Acrocephalus',
#   'sp': 'palustris',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Marsh Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Poretskiy rayon, Chuvashia',
#   'lat': '55.0327',
#   'lng': '46.4763',
#   'alt': '90',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/139010',
#   'file': 'https://xeno-canto.org/139010/download',
#   'file-name': 'XC139010-8001_9.06.2013, Сур майдан, 5-45, бол кам, С .MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC139010-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC139010-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC139010-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC139010-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC139010-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC139010-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC139010-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'C',
#   'length': '0:26',
#   'time': '05:30',
#   'date': '2013-06-09',
#   'uploaded': '2013-06-19',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '138889',
#   'gen': 'Acrocephalus',
#   'sp': 'palustris',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Marsh Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Poretskiy rayon, Chuvashia',
#   'lat': '54.9666',
#   'lng': '46.5587',
#   'alt': '80',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/138889',
#   'file': 'https://xeno-canto.org/138889/download',
#   'file-name': 'XC138889-8096_8.06.2013, р. Сура, Алатырь-Порецкое, Сур майдан, 20-00, бол кам, С .MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC138889-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC138889-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC138889-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC138889-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC138889-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC138889-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC138889-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'C',
#   'length': '2:42',
#   'time': '20:30',
#   'date': '2013-06-08',
#   'uploaded': '2013-06-18',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '138799',
#   'gen': 'Acrocephalus',
#   'sp': 'palustris',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Marsh Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': "Bol'shiye Bikshikhi, Kanashskiy rayon, Chuvashia",
#   'lat': '55.5493',
#   'lng': '47.8626',
#   'alt': '180',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/138799',
#   'file': 'https://xeno-canto.org/138799/download',
#   'file-name': 'XC138799-8008_12.06.2013, Индырчи, бол кам, С .MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC138799-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC138799-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC138799-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC138799-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC138799-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC138799-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC138799-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'C',
#   'length': '0:59',
#   'time': '13:30',
#   'date': '2013-06-12',
#   'uploaded': '2013-06-18',
#   'also': ['Anthus trivialis'],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '135389',
#   'gen': 'Acrocephalus',
#   'sp': 'palustris',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Marsh Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Cheboksary, gorod Cheboksary, Chuvashia',
#   'lat': '56.0906',
#   'lng': '47.2598',
#   'alt': '180',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/135389',
#   'file': 'https://xeno-canto.org/135389/download',
#   'file-name': 'XC135389-001_ 28.05.2013, 8-00, болотная кам, С .MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC135389-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC135389-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC135389-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC135389-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC135389-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC135389-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC135389-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'C',
#   'length': '1:47',
#   'time': '08:00',
#   'date': '2013-05-28',
#   'uploaded': '2013-05-29',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '107394',
#   'gen': 'Acrocephalus',
#   'sp': 'palustris',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Marsh Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Kriushy',
#   'lat': '55.8928',
#   'lng': '48.1498',
#   'alt': '60',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/107394',
#   'file': 'https://xeno-canto.org/107394/download',
#   'file-name': '1368.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC107394-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC107394-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC107394-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC107394-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC107394-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC107394-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC107394-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-nd/2.5/',
#   'q': 'C',
#   'length': '1:28',
#   'time': '8-20',
#   'date': '2012-06-22',
#   'uploaded': '2012-08-12',
#   'also': [],
#   'rmk': 'day song on flood plains in the valley of the Volga River',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '106173',
#   'gen': 'Acrocephalus',
#   'sp': 'palustris',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Marsh Warbler',
#   'rec': 'Albert Lastukhin   ',
#   'cnt': 'Russian Federation',
#   'loc': 'Stemasy',
#   'lat': '54.7878',
#   'lng': '46.527',
#   'alt': '116',
#   'type': 'alarm call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/106173',
#   'file': 'https://xeno-canto.org/106173/download',
#   'file-name': '118.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC106173-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC106173-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC106173-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC106173-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC106173-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC106173-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC106173-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-nd/2.5/',
#   'q': 'C',
#   'length': '0:46',
#   'time': '7-30',
#   'date': '2012-07-19',
#   'uploaded': '2012-07-28',
#   'also': [],
#   'rmk': 'next to the brood',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '145359',
#   'gen': 'Acrocephalus',
#   'sp': 'palustris',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Marsh Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Zvenigovsky District, Mari El Republic',
#   'lat': '56.1511',
#   'lng': '47.4885',
#   'alt': '60',
#   'type': 'alarm call, call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/145359',
#   'file': 'https://xeno-canto.org/145359/download',
#   'file-name': 'XC145359-1016_13.08.2013, Гэс, Заволжье, 7-30, Acrocephalus palustris, Д.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC145359-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC145359-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC145359-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC145359-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC145359-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC145359-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC145359-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'D',
#   'length': '0:50',
#   'time': '07:30',
#   'date': '2013-08-13',
#   'uploaded': '2013-08-15',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '139028',
#   'gen': 'Acrocephalus',
#   'sp': 'palustris',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Marsh Warbler',
#   'rec': 'Albert Lastukhin',
#   'cnt': 'Russian Federation',
#   'loc': 'Poretskiy rayon, Chuvashia',
#   'lat': '55.028',
#   'lng': '46.4571',
#   'alt': '160',
#   'type': 'alarm call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/139028',
#   'file': 'https://xeno-canto.org/139028/download',
#   'file-name': 'XC139028-8021_9.06.2013, Сур майдан, 7-00, бол кам, тр, С .MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC139028-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC139028-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC139028-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/ffts/XC139028-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC139028-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC139028-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LELYWQKUZX/wave/XC139028-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'D',
#   'length': '0:27',
#   'time': '07:00',
#   'date': '2013-06-09',
#   'uploaded': '2013-06-19',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'}]

# %%
def get_birds_names() -> set:
    response = requests.get('https://xeno-canto.org/api/2/recordings?query=loc:Leningradskaya')
    local_data = response.json()['recordings']
    df_local = pd.json_normalize(local_data)
    birds = set(df_local['gen'])
    return birds

# %%
def make_dirs(birds):
    for bird in birds:
        if not os.path.exists(os.path.join(data_dir, bird)):
            os.mkdir(os.path.join(data_dir, bird))

# %%
# теперь по каждому файлу посмотреть например временной ряд mean и вычленить фичи с помощью fbkats и далее строить логистическую регрессию например

# %%
def parse_files(birds):
    count_recs = 0
    for bird in birds:
        print(f'current bird is {bird}')
        response = requests.get(f'https://xeno-canto.org/api/2/recordings?query=gen:{bird}+cnt:russia').json()['recordings']
        if len(response) == 0:
            continue
        cur_df = pd.json_normalize(response)
        for i in range(cur_df.shape[0]):
            id = cur_df.loc[i]['id']
            
            audio = cur_df.loc[i]['file']
            if audio != '':
                audio_response = requests.get(audio)
                with open(os.path.join(data_dir, bird, id) + '.mp3', 'wb') as f:
                    f.write(audio_response.content)

            sono = 'http:' + cur_df.loc[i]['sono.full']
            if sono != 'http:':
                sono_ext = '.' + sono.split('.')[-1]
                sono_response = requests.get(sono)
                with open(os.path.join(data_dir, bird, id + '_sono') + sono_ext, 'wb') as f:
                    f.write(sono_response.content)

            osci = 'http:' + cur_df.loc[i]['osci.large']
            if osci != 'http:':
                osci_ext = '.' + osci.split('.')[-1]
                osci_response = requests.get(osci)
                with open(os.path.join(data_dir, bird, id + '_osci') + osci_ext, 'wb') as f:
                    f.write(osci_response.content)
            count_recs += 1
    return count_recs

# %%
def get_left_df(birds):
    data = []
    for bird in birds:
        response = requests.get(f'https://xeno-canto.org/api/2/recordings?query=gen:{bird}+cnt:russia').json()['recordings']
        if len(response) == 0:
            continue
        data += response
    return pd.json_normalize(data).iloc[:, :-7]

# %%
birds = get_birds_names()
make_dirs(birds)
parse_files(birds)
left_df = get_left_df(birds)

# %%
birds = get_birds_names()
left_df = get_left_df(birds)

# %% [markdown]
# ### Getting our features from audio

# %%
def numify(file: str, step_div):
    values = librosa.load(file)[0]
    step = len(values) / step_div
    print(len(values), step)
    ranges = [range(i * int(step), (i + 1) * int(step)) for i in range(int(step_div) - 1)]
    dfs = []
    for j in range(len(ranges)):
        dfs.append(pd.DataFrame(pd.Series([values[i] for i in ranges[j]]).describe()).transpose())
    df = pd.concat(dfs)
    df['index'] = list(range(len(dfs)))
    df = df.set_index('index')
    return df

# %%
def get_list_files():
    list_files = [os.path.join(dirname, filename) for dirname, _, filenames in os.walk('data') for filename in filenames][1:]
    return list(filter(lambda x: x[-3:] in ('mp3', 'wav'), list_files))

# %%
def numify_all(step_div):
    for file in get_list_files():
        path_list = file.split('/')
        path_list[-1] = path_list[-1][:-4] + '.csv'
        path = '/'.join(path_list)
        numify(file, step_div).to_csv(path)
numify_all(10000)

# %% [markdown]
# ### Joining midterm and shortterm features

# %%
def migrate_features2csv() -> None:
    all_csv_features = [dirname + '/' + file for dirname, _, files in os.walk('data') for file in files if 'wav_' in file]
    mt_features = [file for file in all_csv_features if 'mt' in file]
    for mt in mt_features:
        st = mt.replace('mt', 'st')
        df_mt = pd.read_csv(mt)
        df_mt = df_mt.set_axis([f'm{i}' for i in range(df_mt.shape[-1])], axis=1)
        df_st = pd.read_csv(st)
        df_st = df_st.set_axis([f's{i}' for i in range(df_st.shape[-1])], axis=1)
        final_df = df_st.join(df_mt)
        final_df.to_csv(mt.replace('wav_mt', 'wav'))

# %%
migrate_features2csv()

# %%
def get_birds_enum(numQ: bool = True):
    birds = [dirs for _, dirs, _ in os.walk('data')][0]
    return {i: birds[i] for i in range(len(birds))} if numQ else {birds[i]: i for i in range(len(birds))}

def get_all_df() -> pd.DataFrame:
    csv_files = [dirname + '/' + file for dirname, _, files in os.walk('data') for file in files if 'wav.csv' in file]
    df = pd.read_csv('/Users/juggjup/PycharmProjects/sync-files/mad_nbs/birds/data/Dendrocopos/103937.wav.csv', index_col=0)
    columns = ['index'] + list(df.columns)
    df_all = pd.DataFrame(columns=columns)
    birds_enum = get_birds_enum(False)
    for i, file in enumerate(csv_files):
        df = pd.read_csv(file, index_col=0)
        id = file.split('/')[-1].split('.')[0]
        bird = file.split('/')[1]
        df_all.at[i, 'index'] = id
        for column in columns[1:]:
            df_all.at[i, column] = df[column].dropna().to_numpy()
        df_all.at[i, 'target'] = birds_enum[bird]
        print(f'File {i} {file} ready', end='\r')
    return df_all

# %%
df_all = get_all_df()
# Out:
# File 2514 data/Troglodytes/148474.wav.csv readyy

# %%
df_all.to_csv('data/features.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/juggjup/PycharmProjects/sync-files/mad_nbs/birds/parse.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/Users/juggjup/PycharmProjects/sync-files/mad_nbs/birds/parse.ipynb#Y100sZmlsZQ%3D%3D?line=0'>1</a> df_all.to_csv('data/features.csv')
#
# File ~/PycharmProjects/sync-files/venv/lib/python3.10/site-packages/pandas/core/generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File ~/PycharmProjects/sync-files/venv/lib/python3.10/site-packages/pandas/io/formats/format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File ~/PycharmProjects/sync-files/venv/lib/python3.10/site-packages/pandas/io/formats/csvs.py:266, in CSVFormatter.save(self)
#     247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#    (...)
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
# --> 266     self._save()
#
# File ~/PycharmProjects/sync-files/venv/lib/python3.10/site-packages/pandas/io/formats/csvs.py:271, in CSVFormatter._save(self)
#     269 if self._need_to_save_header:
#     270     self._save_header()
# --> 271 self._save_body()
#
# File ~/PycharmProjects/sync-files/venv/lib/python3.10/site-packages/pandas/io/formats/csvs.py:309, in CSVFormatter._save_body(self)
#     307 if start_i >= end_i:
#     308     break
# --> 309 self._save_chunk(start_i, end_i)
#
# File ~/PycharmProjects/sync-files/venv/lib/python3.10/site-packages/pandas/io/formats/csvs.py:320, in CSVFormatter._save_chunk(self, start_i, end_i)
#     317 data = [res.iget_values(i) for i in range(len(res.items))]
#     319 ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 320 libwriters.write_csv_rows(
#     321     data,
#     322     ix,
#     323     self.nlevels,
#     324     self.cols,
#     325     self.writer,
#     326 )
#
# File writers.pyx:55, in pandas._libs.writers.write_csv_rows()
#
# File ~/PycharmProjects/sync-files/venv/lib/python3.10/site-packages/numpy/core/arrayprint.py:1592, in _array_str_implementation(a, max_line_width, precision, suppress_small, array2string)
#    1586 if a.shape == ():
#    1587     # obtain a scalar and call str on it, avoiding problems for subclasses
#    1588     # for which indexing with () returns a 0d instead of a scalar by using
#    1589     # ndarray's getindex. Also guard against recursive 0d object arrays.
#    1590     return _guarded_repr_or_str(np.ndarray.__getitem__(a, ()))
# -> 1592 return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#
# File ~/PycharmProjects/sync-files/venv/lib/python3.10/site-packages/numpy/core/arrayprint.py:736, in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, legacy)
#     733 if a.size == 0:
#     734     return "[]"
# --> 736 return _array2string(a, options, separator, prefix)
#
# File ~/PycharmProjects/sync-files/venv/lib/python3.10/site-packages/numpy/core/arrayprint.py:513, in _recursive_guard.<locals>.decorating_function.<locals>.wrapper(self, *args, **kwargs)
#     511 repr_running.add(key)
#     512 try:
# --> 513     return f(self, *args, **kwargs)
#     514 finally:
#     515     repr_running.discard(key)
#
# File ~/PycharmProjects/sync-files/venv/lib/python3.10/site-packages/numpy/core/arrayprint.py:546, in _array2string(a, options, separator, prefix)
#     543 # skip over array(
#     544 next_line_prefix += " "*len(prefix)
# --> 546 lst = _formatArray(a, format_function, options['linewidth'],
#     547                    next_line_prefix, separator, options['edgeitems'],
#     548                    summary_insert, options['legacy'])
#     549 return lst
#
# File ~/PycharmProjects/sync-files/venv/lib/python3.10/site-packages/numpy/core/arrayprint.py:889, in _formatArray(a, format_function, line_width, next_line_prefix, separator, edge_items, summary_insert, legacy)
#     885     return s
#     887 try:
#     888     # invoke the recursive part with an initial index and prefix
# --> 889     return recurser(index=(),
#     890                     hanging_indent=next_line_prefix,
#     891                     curr_width=line_width)
#     892 finally:
#     893     # recursive closures have a cyclic reference to themselves, which
#     894     # requires gc to collect (gh-10620). To avoid this problem, for
#     895     # performance and PyPy friendliness, we break the cycle:
#     896     recurser = None
#
# File ~/PycharmProjects/sync-files/venv/lib/python3.10/site-packages/numpy/core/arrayprint.py:846, in _formatArray.<locals>.recurser(index, hanging_indent, curr_width)
#     844 for i in range(trailing_items, 1, -1):
#     845     word = recurser(index + (-i,), next_hanging_indent, next_width)
# --> 846     s, line = _extendLine_pretty(
#     847         s, line, word, elem_width, hanging_indent, legacy)
#     848     line += separator
#     850 if legacy <= 113:
#     851     # width of the separator is not considered on 1.13
#
# KeyboardInterrupt:
